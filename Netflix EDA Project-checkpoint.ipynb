# %%
# %%time
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import ydata_profiling as prf
# %matplotlib inline
sns.set()
# Out:
# CPU times: total: 328 ms
# Wall time: 3.47 s

# %%
netflix=pd.read_csv("D:/Python/EDA/netflix_titles_nov_2019.csv")
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5837 entries, 0 to 5836
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5837 non-null   int64
#  1   title         5837 non-null   object
#  2   director      3936 non-null   object
#  3   cast          5281 non-null   object
#  4   country       5410 non-null   object
#  5   date_added    5195 non-null   object
#  6   release_year  5837 non-null   int64
#  7   rating        5827 non-null   object
#  8   duration      5837 non-null   object
#  9   listed_in     5837 non-null   object
#  10  description   5837 non-null   object
#  11  type          5837 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 547.3+ KB

# %%
netflix.describe()
# Out:
#             show_id  release_year
# count  5.837000e+03   5837.000000
# mean   7.730079e+07   2013.688539
# std    9.479777e+06      8.419088
# min    2.698800e+05   1925.000000
# 25%    8.004520e+07   2013.000000
# 50%    8.016353e+07   2016.000000
# 75%    8.024188e+07   2018.000000
# max    8.122720e+07   2020.000000

# %%
netflix.shape
# Out:
# (5837, 12)

# %%
netflix.dtypes
# Out:
# show_id          int64
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# type            object
# dtype: object

# %% [markdown]
# # About Data
# ### This dataset contains data collected from Netflix of different TV shows and movies from the year 2008 to 2021.
#
# - type: Gives information about 2 different unique values one is TV Show and another is Movie
# - title: Gives information about the title of Movie or TV Show
# - director: Gives information about the director who directed the Movie or TV Show
# - cast: Gives information about the cast who plays role in Movie or TV Show
# - release_year: Gives information about the year when Movie or TV Show was released
# - date_added : Gives information about when movie was uploaded on netflix
# - rating: Gives information about the Movie or TV Show are in which category (eg like the movies are only for students, or adults, etc)
# - duration: Gives information about the duration of Movie or TV Show
# - listed_in: Gives information about the genre of Movie or TV Show
# - description: Gives information about the description of Movie or TV Show

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### checking for duplicate rows in dataset

# %%
netflix[netflix.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, type]
# Index: []

# %% [markdown]
# ### It is found that there are no duplicates rows in datasets

# %% [markdown]
# ### Checking for null values in dataset

# %%
m=netflix.isnull().sum()
total=len(netflix)
miss=(m/total)*100  # len(netflix) shows total number of rows
miss_data=pd.concat([m,miss],axis=1,keys=['Missing values','missing values(%)'])
miss_data
# Out:
#               Missing values  missing values(%)
# show_id                    0           0.000000
# title                      0           0.000000
# director                1901          32.568100
# cast                     556           9.525441
# country                  427           7.315402
# date_added               642          10.998801
# release_year               0           0.000000
# rating                    10           0.171321
# duration                   0           0.000000
# listed_in                  0           0.000000
# description                0           0.000000
# type                       0           0.000000

# %% [markdown]
# ### Dropping the those rows in which null values are present in cast or director features

# %%
netflix=netflix.dropna(how='any',subset=['cast','director'])

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3588 entries, 1 to 5836
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3588 non-null   int64
#  1   title         3588 non-null   object
#  2   director      3588 non-null   object
#  3   cast          3588 non-null   object
#  4   country       3482 non-null   object
#  5   date_added    3557 non-null   object
#  6   release_year  3588 non-null   int64
#  7   rating        3584 non-null   object
#  8   duration      3588 non-null   object
#  9   listed_in     3588 non-null   object
#  10  description   3588 non-null   object
#  11  type          3588 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 364.4+ KB

# %% [markdown]
# ### Replacing the null values in country and rating

# %%
netflix.fillna({'country':'missing','rating':'missing'},inplace=True)
netflix.isnull().sum()
# Out:
# show_id          0
# title            0
# director         0
# cast             0
# country          0
# date_added      31
# release_year     0
# rating           0
# duration         0
# listed_in        0
# description      0
# type             0
# dtype: int64

# %% [markdown]
# ### Replacing rows in which date_added values are null

# %%
netflix = netflix.dropna()

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3557 entries, 1 to 5836
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3557 non-null   int64
#  1   title         3557 non-null   object
#  2   director      3557 non-null   object
#  3   cast          3557 non-null   object
#  4   country       3557 non-null   object
#  5   date_added    3557 non-null   object
#  6   release_year  3557 non-null   int64
#  7   rating        3557 non-null   object
#  8   duration      3557 non-null   object
#  9   listed_in     3557 non-null   object
#  10  description   3557 non-null   object
#  11  type          3557 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 361.3+ KB

# %%
netflix.isnull().sum()
# Out:
# show_id         0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# type            0
# dtype: int64

# %% [markdown]
# ###  Converting data_added data type from object to datetime

# %%
netflix['date_added']=pd.to_datetime(netflix['date_added'])

# %%
netflix.head()
# Out:
#     show_id                                title                    director  \
# 1  81197050  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2  81213894                      The Zoya Factor             Abhishek Sharma
# 3  81082007                            Atlantics                   Mati Diop
# 5  81172754                         Crazy people                Moses Inwang
# 6  81120982                       I Lost My Body               Jérémy Clapin
#
#                                                 cast  \
# 1                                  Christian Morales
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 5  Ramsey Nouah, Chigul, Sola Sobowale, Ireti Doy...
# 6  Hakim Faris, Victoire Du Bois, Patrick d'Assum...
#
#                     country date_added  release_year rating duration  \
# 1                   missing 2019-11-30          2019   TV-G   67 min
# ...

# %%
netflix.info() # we changed the data type of date_added from object to datetime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3557 entries, 1 to 5836
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3557 non-null   int64
#  1   title         3557 non-null   object
#  2   director      3557 non-null   object
#  3   cast          3557 non-null   object
#  4   country       3557 non-null   object
#  5   date_added    3557 non-null   datetime64[ns]
#  6   release_year  3557 non-null   int64
#  7   rating        3557 non-null   object
#  8   duration      3557 non-null   object
#  9   listed_in     3557 non-null   object
#  10  description   3557 non-null   object
#  11  type          3557 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 361.3+ KB

# %% [markdown]
# ### Checking number of unique values in each columns

# %%
netflix.nunique()
# Out:
# show_id         3557
# title           3540
# director        2796
# cast            3434
# country          407
# date_added       954
# release_year      67
# rating            15
# duration         171
# listed_in        268
# description     3549
# type               2
# dtype: int64

# %%
netflix.describe(include='all',datetime_is_numeric=True)
# Out:
#              show_id        title                director         cast  \
# count   3.557000e+03         3557                    3557         3557
# unique           NaN         3540                    2796         3434
# top              NaN  The Silence  Raúl Campos, Jan Suter  Samuel West
# freq             NaN            3                      18           10
# mean    7.610989e+07          NaN                     NaN          NaN
# min     2.698800e+05          NaN                     NaN          NaN
# 25%     8.000207e+07          NaN                     NaN          NaN
# 50%     8.015756e+07          NaN                     NaN          NaN
# 75%     8.024485e+07          NaN                     NaN          NaN
# max     8.122720e+07          NaN                     NaN          NaN
# std     1.168996e+07          NaN                     NaN          NaN
#
#               country                     date_added  release_year rating  \
# ...

# %% [markdown]
# # EDA
#
# -  What different types of show or movie are uploaded on Netflix?
# - Correlation between the features
# - Distribution of Ratings
# - Top movie and tv shows watched
# - Top movies and tv show of each year
# - Which has the highest rating in Tv show or Movies
# - Highest watched genres on Netflix
# - Released movie over the years

# %%
netflix.type.value_counts().to_frame('value count of types')
# Out:
#          value count of types
# Movie                    3487
# TV Show                    70

# %% [markdown]
# ### Pairwise correlation between columns

# %%
netflix.corr()
# Out:
#                show_id  release_year
# show_id       1.000000      0.586304
# release_year  0.586304      1.000000

# %%
plt.subplots(figsize=(2,4))
sns.heatmap(netflix.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Top shows in each movie and tv show

# %%
netflix.groupby('type')['title'].agg(pd.Series.mode)
# Out:
# type
# Movie                                            The Silence
# TV Show    [46, 7 (Seven), A.I.C.O., Age of Rebellion, Ak...
# Name: title, dtype: object

# %% [markdown]
# ### Top five shows yearwise in each type movie and tv shows

# %%
netflix.groupby(['type','release_year'])['title'].agg(pd.Series.mode)
# Out:
# type     release_year
# Movie    1942                                         The Battle of Midway
#          1944                                             Tunisian Victory
#          1945                                      Know Your Enemy - Japan
#          1946                           [Let There Be Light, The Stranger]
#          1947                                                  Thunderbolt
#                                                ...
# TV Show  2015            [Akulah Balqis, Gonul, Hjørdis, Jonathan Stran...
#          2016            [46, Bring It On, Ghost, Cheese in the Trap, J...
#          2017            [Ari Shaffir: Double Negative, Bright: The Mus...
#          2018            [A.I.C.O., Age of Rebellion, Bitter Daisies, B...
#          2019            [7 (Seven), Bolívar, Crime Diaries: Night Out,...
# Name: title, Length: 80, dtype: object

# %% [markdown]
# ### Distribution of shows among rating
# - Rating with TV-MA has highest number of shows

# %%
sns.countplot(x=netflix['rating'],orient='v')
plt.xticks(rotation=90)
plt.show()

# %%
netflix.groupby('type')['rating'].agg(pd.Series.mode).to_frame('Top rating type')
# Out:
#         Top rating type
# type
# Movie             TV-MA
# TV Show           TV-MA

# %%
netflix.head()
# Out:
#     show_id                                title                    director  \
# 1  81197050  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2  81213894                      The Zoya Factor             Abhishek Sharma
# 3  81082007                            Atlantics                   Mati Diop
# 5  81172754                         Crazy people                Moses Inwang
# 6  81120982                       I Lost My Body               Jérémy Clapin
#
#                                                 cast  \
# 1                                  Christian Morales
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 5  Ramsey Nouah, Chigul, Sola Sobowale, Ireti Doy...
# 6  Hakim Faris, Victoire Du Bois, Patrick d'Assum...
#
#                     country date_added  release_year rating duration  \
# 1                   missing 2019-11-30          2019   TV-G   67 min
# ...

# %% [markdown]
# ### Splitting the listed in into different genre

# %%
new_genre=netflix['listed_in'].str.split(",",2)

# %%
new_genre
# Out:
# 1                  [Documentaries,  International Movies]
# 2              [Comedies,  Dramas,  International Movies]
# 3       [Dramas,  Independent Movies,  International M...
# 5           [Comedies,  International Movies,  Thrillers]
# 6       [Dramas,  Independent Movies,  International M...
#                               ...
# 5831                      [Dramas,  International Movies]
# 5832                        [Cult Movies,  Horror Movies]
# 5833                                      [Horror Movies]
# 5834                      [Dramas,  International Movies]
# 5836            [Dramas,  Independent Movies,  Thrillers]
# Name: listed_in, Length: 3557, dtype: object

# %% [markdown]
# ## Adding new features

# %%
netflix['genre1']=new_genre.str.get(0)
netflix['genre2']=new_genre.str.get(1)
netflix['genre3']=new_genre.str.get(2)

# %%
netflix.head(100)
# Out:
#       show_id                                title  \
# 1    81197050  Guatemala: Heart of the Mayan World
# 2    81213894                      The Zoya Factor
# 3    81082007                            Atlantics
# 5    81172754                         Crazy people
# 6    81120982                       I Lost My Body
# ..        ...                                  ...
# 165  70209267                 A Holiday Engagement
# 166  70306305                      Christmas Crush
# 167  70262831                           Dear Santa
# 168  70113005                           District 9
# 169  70052286                Kicking and Screaming
#
#                        director  \
# 1    Luis Ara, Ignacio Jaunsolo
# 2               Abhishek Sharma
# 3                     Mati Diop
# 5                  Moses Inwang
# 6                 Jérémy Clapin
# ..                          ...
# 165                    Jim Fall
# 166              Marita Grabiak
# 167             Jason Priestley
# ...

# %% [markdown]
# ### Removing the lsited_in column

# %%
netflix.drop('listed_in',axis=1,inplace=True)

# %%
netflix.head()
# Out:
#     show_id                                title                    director  \
# 1  81197050  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2  81213894                      The Zoya Factor             Abhishek Sharma
# 3  81082007                            Atlantics                   Mati Diop
# 5  81172754                         Crazy people                Moses Inwang
# 6  81120982                       I Lost My Body               Jérémy Clapin
#
#                                                 cast  \
# 1                                  Christian Morales
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 5  Ramsey Nouah, Chigul, Sola Sobowale, Ireti Doy...
# 6  Hakim Faris, Victoire Du Bois, Patrick d'Assum...
#
#                     country date_added  release_year rating duration  \
# 1                   missing 2019-11-30          2019   TV-G   67 min
# ...

# %% [markdown]
# __Q1)__ Movies made on year basis?

# %%
netflix.groupby('release_year')['release_year'].count().sort_values(ascending=False)
# Out:
# release_year
# 2017    567
# 2018    557
# 2016    509
# 2015    317
# 2019    302
#        ...
# 1969      1
# 1944      1
# 1972      1
# 1977      1
# 1942      1
# Name: release_year, Length: 67, dtype: int64

# %% [markdown]
# __Q2)__ Movies made on year basis according to genre?

# %%
netflix.groupby('genre1')['release_year'].count().sort_values(ascending=False)
# Out:
# genre1
# Dramas                          988
# Comedies                        714
# Action & Adventure              523
# Documentaries                   309
# Children & Family Movies        290
# Stand-Up Comedy                 244
# Horror Movies                   184
# International Movies             72
# Classic Movies                   40
# Thrillers                        37
# Movies                           29
# International TV Shows           21
# Independent Movies               16
# Crime TV Shows                   14
# Music & Musicals                 12
# British TV Shows                 11
# Sci-Fi & Fantasy                 10
# Anime Features                    9
# Cult Movies                       8
# Docuseries                        6
# Kids' TV                          5
# TV Shows                          5
# Stand-Up Comedy & Talk Shows      4
# Anime Series                      3
# Romantic Movies                   2
# TV Comedies                       1
# ...

# %%
netflix.groupby('genre2')['release_year'].count().sort_values(ascending=False)
# Out:
# genre2
#  International Movies        1003
#  Dramas                       451
#  Independent Movies           387
#  Comedies                     249
#  Thrillers                    139
#  Romantic Movies               86
#  Music & Musicals              72
#  Sci-Fi & Fantasy              71
#  Sports Movies                 50
#  Faith & Spirituality          36
#  Horror Movies                 36
#  Anime Features                31
#  Cult Movies                   27
#  Children & Family Movies      17
#  LGBTQ Movies                  16
#  International TV Shows        15
#  Classic Movies                13
#  Documentaries                 11
#  TV Comedies                   11
#  TV Dramas                      9
#  Stand-Up Comedy                8
#  Korean TV Shows                7
#  Docuseries                     5
#  Romantic TV Shows              5
#  Crime TV Shows                 3
#  Kids' TV                       1
# Name: release_year, dtype: int64

# %%
netflix.groupby('genre3')['release_year'].count().sort_values(ascending=False)
# Out:
# genre3
#  International Movies            569
#  Romantic Movies                 244
#  Thrillers                       174
#  Music & Musicals                113
#  Independent Movies              109
#  Sci-Fi & Fantasy                 77
#  Sports Movies                    64
#  LGBTQ Movies                     34
#  Dramas                           33
#  TV Dramas                        15
#  Cult Movies                       6
#  Faith & Spirituality              6
#  Spanish-Language TV Shows         5
#  Romantic TV Shows                 5
#  Comedies                          5
#  International TV Shows            4
#  Horror Movies                     4
#  Classic Movies                    4
#  TV Action & Adventure             3
#  TV Horror                         2
#  TV Mysteries                      2
#  TV Thrillers                      2
#  Korean TV Shows                   1
#  Stand-Up Comedy & Talk Shows      1
#  TV Sci-Fi & Fantasy               1
# ...

# %% [markdown]
# ### Observation:
#
# - From the above we can see that with passing years more movies are being made year by year
#
# - The graph below shows that there is a sudden increase in the creation of movies in year 2016 as compared to year 2015

# %%
sns.countplot(x='release_year',data=netflix).set_title('count plot for movies with passing year')
sns.set(rc={'figure.figsize':(40,20)})
plt.xticks(rotation=90)
plt.show()
